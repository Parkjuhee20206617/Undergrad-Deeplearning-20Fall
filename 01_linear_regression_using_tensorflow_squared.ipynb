# %% [markdown]
# **라이브러리 Import 하기**

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **X and Y data (given)**

# %%
x_train = [1, 2, 3, 4, 5, 6, 7]
y_train = [3, 6, 9, 12, 15, 18, 21] #y=3x

signal_length = len(x_train)
y_noise = np.random.normal(0, 1, signal_length)

y_train = y_train + y_noise
# 다음의 것들도 해보시오
#y_train = [2, 4, 6] # 그냥 x_train 에 2배 곱해서 생성
#y_train = [3, 5, 7]

# %%
plt.plot(x_train, y_train,'.-')
plt.grid()

# %% [markdown]
# **Initialization**

# %%
useRandom = False

# %%
if useRandom:
    W = tf.Variable(tf.random_normal([1]), name='weight')
    b = tf.Variable(tf.random_normal([1]), name='bias')
else:
    w0 = 6.0;
    b0 = 3.0;

    W = tf.Variable(w0*tf.ones([1]), name='weight')
    b = tf.Variable(b0*tf.ones([1]), name='bias')

# %% [markdown]
# Our hypothesis
# $$H(X)=Wx+b$$

# %%
hypothesis = x_train * W + b

# %% [markdown]
# **cost/loss function 정의하기**
# * loss of one training example:
# $$loss = \mathcal{L}(\hat{y}, y) = (\hat y^{(i)} - y^{(i)})^2 \tag{1}$$

# %%
loss = tf.reduce_mean(tf.square(hypothesis - y_train))

# %% [markdown]
# **Optimizer**

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(loss)

# %% [markdown]
# **Launch the graph in a session**

# %%
sess = tf.Session()

# %% [markdown]
# **Initializes global variables in the graph.**

# %%
sess.run(tf.global_variables_initializer())

# %%
nb_epoch = 2001
vloss = []
vb =  []
vw = [] 

for step in range(nb_epoch):
    sess.run(train)
    loss1 = sess.run(loss)
    w1 = sess.run(W)[0] # 기울기
    b1 = sess.run(b)[0] # bias
    
    vloss.append(loss1)
    vb.append(b1)
    vw.append(w1)

    if step % 100 == 0: # 100번마다
       
        print(step,'\t', loss1,'\t', w1,'\t',b1)
# Out:
# 0 	 85.25786 	 4.593657 	 2.7087474
# 100 	 0.4339967 	 2.7352426 	 1.7325759
# 200 	 0.27177247 	 2.8145583 	 1.3398099
# 300 	 0.19669263 	 2.8685172 	 1.0726092
# 400 	 0.16194446 	 2.9052258 	 0.8908307
# 500 	 0.14586242 	 2.9301987 	 0.7671655
# 600 	 0.13841936 	 2.9471881 	 0.68303525
# 700 	 0.1349746 	 2.958746 	 0.6258009
# 800 	 0.13338034 	 2.9666088 	 0.5868645
# 900 	 0.13264245 	 2.9719582 	 0.56037515
# 1000 	 0.13230102 	 2.9755971 	 0.5423547
# 1100 	 0.13214298 	 2.978073 	 0.53009534
# 1200 	 0.13206983 	 2.979757 	 0.5217553
# 1300 	 0.13203588 	 2.980903 	 0.51608145
# 1400 	 0.13202012 	 2.9816823 	 0.5122216
# 1500 	 0.13201287 	 2.9822125 	 0.50959575
# 1600 	 0.13200966 	 2.9825733 	 0.5078093
# 1700 	 0.13200802 	 2.9828188 	 0.5065941
# 1800 	 0.13200733 	 2.9829857 	 0.5057673
# 1900 	 0.13200697 	 2.9830992 	 0.505205
# 2000 	 0.13200685 	 2.9831765 	 0.50482243

# %%
plt.plot(vloss[:20],'.-')
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# **TODO**

# %%
plt.plot(vb[:20],'.-')
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
plt.plot(vw[:20],'.-')
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# **학습완료**

# %%
w1 = sess.run(W)[0] # 기울기
b1 = sess.run(b)[0] # bias

# %% [markdown]
# 출력해보기

# %%
print(w1, b1)
# Out:
# 2.9831765 0.50482243

# %%
str1 = 'y = ' + str(w1) +'x + ' + str(b1)
print(str1)
# Out:
# y = 2.9831765x + 0.50482243

# %%
plt.figure(figsize=(6,4)) # figsize를 바꾸어보세요
plt.plot(x_train, y_train,'o') #train data 그리기

# 직선 그래프를 그리기 위한 코드
# 그래프의 x좌표를 일정 간격으로 설정함
x1 = np.linspace(np.min(x_train)-1, np.max(x_train)+1)
y1 = w1*x1 + b1
plt.plot(x1, y1)

plt.grid() # 격자
#plt.axis((np.min(x_train) - 1, np.max(x_train) + 1, np.min(y_train) - 1, np.max(y_train) + 1))
plt.title(str1)
# Out:
# Text(0.5, 1.0, 'y = 2.9831765x + 0.50482243')

# %% [markdown]
# # **R-Squared**

# %% [markdown]
# R-squared 란? 모델이 데이터에 얼마나 적합한 지 수치적으로 결정하는 방법입니다.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import random
# %matplotlib inline

# %% [markdown]
# # **MSE(Mean Squared Error)**

# %% [markdown]
# $$ \frac{(실제값-예측값)^2}{데이터수} $$

# %%
x=[[1],[2],[3],[4],[5]]
y=[[1],[5],[6],[7],[11]]
y=np.array(y)
x=np.array(x)
mean=(1+5+6+7+11)/5 #데이터의 평균값
print(y)
# Out:
# [[ 1]
#  [ 5]
#  [ 6]
#  [ 7]
#  [11]]

# %%
plt.plot(x,y,marker='o',linestyle='')
plt.plot('X')
plt.plot('Y')

# %%
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.plot(x,y,marker='o',linestyle='')
plt.plot(x,lr.predict(x),color = 'red')
plt.axhline(y=mean, xmin=0.04, xmax=0.96, color = 'black')

# %%
mean_squared_error(y, lr.predict(x))
# Out:
# 0.7200000000000001

# %%
print(lr.predict(x))
# Out:
# [[ 1.6]
#  [ 3.8]
#  [ 6. ]
#  [ 8.2]
#  [10.4]]

# %%
def myMSE(X,Y,line):
  err=0
  #for i in range (len(X)):     #예측값 MSE구하기
  #    err+=(Y[i][0]-line[i][0])**2

  if (str(type(line)) == "<class 'float'>"): #평균MSE 구하기
      for i in range(len(X)):
          err += (Y[i][0]-line)**2

  else:
      for i in range(len(X)):  #예측값 Mse 구하기
          err +=(Y[i][0]-line[i][0])**2

  MSE = err/len(X)
  return MSE

# %%
print("MSE :", myMSE(x,y,lr.predict(x)))
# Out:
# MSE : 0.7200000000000001

# %% [markdown]
# # **R squared**

# %% [markdown]
# $$ R^2 = 1- \frac{MSE of regression line}{MSEof the average of the data} $$

# %%
lr.score(x,y)
# Out:
# 0.9307692307692308

# %%
def myRsq(X,Y,model):

    #평균구하기
    hap=0
    for i in range(len(X)):
        hap += Y[i][0]
    mean = float(hap/len(X))
    print("평균:", mean)

    #모델 fit 하기 
    model.fit(X,Y)

    #MSE와 R-squared 구하기
    reg_mse=myMSE(X,Y,model.predict(X))
    avg_mse=myMSE(X,Y,mean)
    r=1-(reg_mse/avg_mse)

    #출력
    #print("MSEof regression line:", reg_mse)
    #print("MSE of average line:", avg_mse)
    print( "R-squared:", r)

# %%
myRsq(x,y,LinearRegression())
# Out:
# 평균: 6.0
# R-squared: 0.9307692307692308

# %% [markdown]
# # **100개 데이터로 해보기**

# %% [markdown]
# # **데이터가 선형 모델에 적합한 경우**

# %% [markdown]
# **1. 데이터 만들기**

# %%
data=100 #데이터 개수 정하기

# %%
#x_train 데이터 만들기
x_train=[]
for i in range(1,data+1):
  x_train.append([i])

x_train=np.array(x_train)
x_train.shape
# Out:
# (100, 1)

# %%
#y_train 데이터 만들기
y_train1=[]
for i in range(1,data+1): #y_train에 노이즈 만들어서 넣기
  y_train1.append([i+random.uniform(-20,20)]) #난수발생시켜서 노이즈 만들기
  
y_train1=np.array(y_train1)
y_train1.shape
# Out:
# (100, 1)

# %%
plt.plot(x_train, y_train1, marker='o', linestyle='')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# **2. 모델에 넣기**

# %%
lr.fit(x_train,y_train1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#평균값 구하기
mean=0
for i in y_train1:
    for j in i:
        mean+=j
mean=mean/data
print(mean)
# Out:
# 48.13556586553031

# %%
#예측한 값과 평균 그려보기
plt.plot(x_train, y_train1, marker='o', linestyle='')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x_train,lr.predict(x_train), color='red')
plt.axhline(y=mean, xmin=0.04, xmax=0.96, color='black')

# %% [markdown]
# 함수와 내가 만든 함수 비교하기

# %%
lr.score(x_train,y_train1)
# Out:
# 0.8541423861464071

# %%
myRsq(x_train, y_train1, LinearRegression())
# Out:
# 평균: 48.13556586553031
# R-squared: 0.8541423861464073

# %% [markdown]
# **데이터가 선형모델에 부적합한 경우**

# %%
y_train2=[]
for i in range(1,data+1): #y_train에 노이즈 만들어서 넣기
    y_train2.append([i+random.uniform(-400,400)]) #난수발생시켜서 노이즈 만들기

y_train2=np.array(y_train2)
y_train2.shape
# Out:
# (100, 1)

# %%
plt.plot(x_train, y_train2, marker='o', linestyle='')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
mean=0
for i in y_train2:
    for j in i:
        mean += j
mean= mean/data
print(mean)
# Out:
# 59.97286622035832

# %%
lr.fit(x_train, y_train2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.plot(x_train, y_train2, marker='o', linestyle='')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x_train, lr.predict(x_train),color='red')
plt.axhline(y=mean, xmin=0.04, xmax=0.96, color='black')

# %%
lr.score(x_train, y_train2)
# Out:
# 0.05979262970455157

# %%
myRsq(x_train,y_train2, LinearRegression())
# Out:
# 평균: 59.97286622035832
# R-squared: 0.059792629704551126
